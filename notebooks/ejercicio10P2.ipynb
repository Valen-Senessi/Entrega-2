# %%
import sys
import os

# Obtener la ruta absoluta del directorio raíz del proyecto
sys.path.append(os.path.abspath("../src"))

from funciones import *

rounds = [
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
}
]

ranking_final = []

for n in range(5):
    print (" ")
    print ("RONDA NÚMERO: ", n + 1)
    print (" ")
    imprimirRonda(rounds,n)
    print("")
    
imprimirRankingFinal(rounds)
# Out:
#
# RONDA NÚMERO:  1
#
# Shadow =
#  kills : 2   assists : 1   deaths : True  puntos :  6
#
# Blaze =
#  kills : 1   assists : 0   deaths : False  puntos :  3
#
# Viper =
#  kills : 1   assists : 2   deaths : True  puntos :  4
#
# Frost =
#  kills : 0   assists : 1   deaths : False  puntos :  1
#
# Reaper =
#  kills : 1   assists : 1   deaths : False  puntos :  4
#
# El MVP de la ronda es:  Shadow
#
#
# RONDA NÚMERO:  2
#
# Shadow =
#  kills : 0   assists : 2   deaths : False  puntos :  2
#
# Blaze =
#  kills : 2   assists : 0   deaths : True  puntos :  5
#
# Viper =
#  kills : 1   assists : 1   deaths : False  puntos :  4
#
# Frost =
#  kills : 2   assists : 1   deaths : True  puntos :  6
#
# Reaper =
#  kills : 0   assists : 1   deaths : False  puntos :  1
#
# El MVP de la ronda es:  Frost
#
#
# RONDA NÚMERO:  3
#
# Shadow =
#  kills : 1   assists : 0   deaths : False  puntos :  3
#
# Blaze =
#  kills : 2   assists : 2   deaths : True  puntos :  7
#
# Viper =
#  kills : 1   assists : 1   deaths : True  puntos :  3
#
# Frost =
#  kills : 0   assists : 1   deaths : False  puntos :  1
#
# Reaper =
#  kills : 1   assists : 1   deaths : False  puntos :  4
#
# El MVP de la ronda es:  Blaze
#
#
# RONDA NÚMERO:  4
#
# Shadow =
#  kills : 2   assists : 1   deaths : False  puntos :  7
#
# Blaze =
#  kills : 1   assists : 0   deaths : True  puntos :  2
#
# Viper =
#  kills : 0   assists : 2   deaths : False  puntos :  2
#
# Frost =
#  kills : 1   assists : 1   deaths : True  puntos :  3
#
# Reaper =
#  kills : 1   assists : 1   deaths : False  puntos :  4
#
# El MVP de la ronda es:  Shadow
#
#
# RONDA NÚMERO:  5
#
# Shadow =
#  kills : 1   assists : 2   deaths : True  puntos :  4
#
# Blaze =
#  kills : 0   assists : 1   deaths : False  puntos :  1
#
# Viper =
#  kills : 2   assists : 0   deaths : True  puntos :  5
#
# Frost =
#  kills : 1   assists : 1   deaths : False  puntos :  4
#
# Reaper =
#  kills : 1   assists : 1   deaths : True  puntos :  3
#
# El MVP de la ronda es:  Viper
#
# [('Shadow', {'kills': 6, 'assists': 6, 'deaths': 2, 'puntos': 22, 'MVPs': 2}), ('Blaze', {'kills': 6, 'assists': 3, 'deaths': 3, 'puntos': 18, 'MVPs': 1}), ('Viper', {'kills': 5, 'assists': 6, 'deaths': 3, 'puntos': 18, 'MVPs': 1}), ('Reaper', {'kills': 4, 'assists': 5, 'deaths': 1, 'puntos': 16, 'MVPs': 0}), ('Frost', {'kills': 4, 'assists': 5, 'deaths': 2, 'puntos': 15, 'MVPs': 1})]
